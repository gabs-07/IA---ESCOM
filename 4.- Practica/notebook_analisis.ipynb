# %% [markdown]
# # Análisis y Preprocesamiento de Datasets
#
# Este notebook demuestra el análisis de dos datasets de clasificación de Kaggle.

# %%
from analisis_datos import procesar_dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar y procesar primer dataset
ruta_dataset1 = "Titanic-Dataset.csv.csv"
df1 = procesar_dataset(ruta_dataset1, "Dataset1")
